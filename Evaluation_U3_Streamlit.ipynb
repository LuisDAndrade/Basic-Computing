# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDAndrade/Basic-Computing/blob/main/Evaluation_U3_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TECNM | CAMPUS PABELLÓN DE ARTEAGA** ⚙️💡
#
# #**Master of Science in Mechatronics Engineering** 📊

# %% [markdown]
# ---
# ##**BASIC COMPUTING I 🧑🏻‍💻**
# ---
# ##***TEST U3 STREAMLIT 🚀***
#
# * **Professor: Dr. Francisco Villanueva Mejia👨🏻‍🏫**
#
# * **Student: Luis Bryant Díaz Andrade 🧑🏻‍💻**
#
# *Date: May 30th, 2023*
#
# ---

# %% [markdown]
# ##**i. Introduction.**
#
# **IN THIS PROGRAM WE WILL CARRY OUT THE PROCEDURE TO MAKE A WEB PAGE, IN MY CASE I DID IT DESCRIBING THE ARTIFICIAL LIGHTING LABORATORY BELONGING TO THE TECNM|CAMPUS PABELLÓN DE ARTEAGA, I PUT IMAGES, DIRECT LINKS, ANIMATIONS AND VIDEOS.**

# %%
# !pip install streamlit -q
# !pip install streamlit-lottie
# !pip install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %%writefile app.py

import streamlit as st
import requests
from streamlit_lottie import st_lottie
from PIL import Image

#Funcion para nuestra animacion
def load_lottieurl(url):
  r = requests.get(url)
  if r.status_code != 200:
    return None
  return r.json()

lottie_coding = load_lottieurl("https://assets9.lottiefiles.com/packages/lf20_2glqweqs.json")
imagen_video = Image.open("/content/FB_IMG_1558890026501.jpg") 
LIA = Image.open('/content/LIAPNG.png')
Farm = load_lottieurl('https://assets3.lottiefiles.com/packages/lf20_Lpuvp7YT5K.json')
ITPA = Image.open('/content/ITPA.png')
LED = load_lottieurl('https://assets10.lottiefiles.com/private_files/lf30_xxlyxctc.json')


with st.container():

   st.markdown("<h1 style='text-align: center; color: black;'>🌱LIA. LABORATORIO DE ILUMINACIÓN ARTIFICIAL🌱</h1>", unsafe_allow_html=True)



left_column, right_column = st.columns(2)
with left_column:
    st.image(LIA)
with right_column:
    st.image(ITPA)

with st.container():    
    st.write("---")
    st.markdown("<h2 style='text-align: center; color: black;'>LIA🌻🌻</h2>", unsafe_allow_html=True)
    st.write("BREVE HISTORIA🐝")
    st.write(''' 

Durante el 2017 se creó el Laboratorio de Iluminación Artificial (LIA) dentro del Tecnológico Nacional de México campus Pabellón de Arteaga gracias al apoyo recibido por parte de la Convocatoria de Infraestructura Científica y Tecnológica del CONACyT (INFRA‐2016‐01, Project No. 270665).

La creación de nuestro Laboratorio de Iluminación Artificial tiene como objetivo principal el desarrollo, la creación de conocimiento científico y aplicación tecnológica para contribuir en la problemática relacionada con la Soberanía Alimentaría, Producción de Alimentos Sanos y Agrotecnología con énfasis en el cuidado de los recursos naturales.

En LIA, los proyectos de investigación básica y aplicada han sido planeados y desarrollados de acuerdo al enfoque de la SADER federal y de la Secretaria de Desarrollo Rural y Agroempresarial del Gobierno del Estado de Aguascalientes, impulsando las actividades del sector agroalimentario y agroindustrial, además de la Electrónica y las TICs que son estrategias de la agenda de Innovación del Estado creada por CONACyT, junto con los objetivos de la agenda de Seguridad Alimentaria del Plan Nacional de Desarrollo y algunos de los objetivos (2, 11, y 12) de la Organización de las Naciones Unidas.

Las acciones planeadas dentro de LIA son puntos críticos presentados por instituciones como la FAO (La Organización de las Naciones Unidas para la Alimentación y la Agricultura), OMS (Organización Mundial de la Salud), Programa Mundial de Alimentos (PMA), FIDA (Fondo Internacional de Desarrollo Agrícola) y son Agricultura Sustentable y Protegida, Seguridad Alimentaria, Enfermedades Transmitidas por los Alimentos, Sanidad Vegetal, entre otros.
 
  ''')

    st.write("[Más información 🌱>](http://pabellon.tecnm.mx/LIA/index.html)")

with st.container():
   st.write("---")
   left_column, right_column = st.columns(2)
   with left_column:
    st.header("¿Quienes Somos?")
    st.subheader ('LIA')
    st.write('El Laboratorio de Iluminación Artificial se encarga de aportar conocimientos científicos y tecnológicos con responsabilidad social a través iniciativas sustentables que contribuyan al mejoramiento de las condiciones de vida en el sector agroindustrial; siendo uno de los pocos laboratorios en el mundo con equipamiento altamente especializado para analizar la interacción de la luz con las plantas y alimentos.' )
    st.write("[TECNM| CAMPUS PABELLON DE ARTEAGA | LIA >](http://pabellon.tecnm.mx/LIA/quienessomos.html)")
   with right_column:
    st_lottie(Farm, height=350, key="coding")

AG = load_lottieurl('https://assets5.lottiefiles.com/packages/lf20_pakb3a6l.json')
VI = load_lottieurl('https://assets5.lottiefiles.com/packages/lf20_qc1dgfda.json')
CO = load_lottieurl('https://assets5.lottiefiles.com/packages/lf20_1lvsledo.json')

with st.container():
   st.write("---")
   st.write("---")

   st.header('💦GENERALIDADES💦')
  
   a,b = st.columns(2)

   with a: 
    st.write("---")
    st.subheader('💨Objetivo General')
    st.write('Profundizar y clariﬁcar los fenómenos no explicados hasta el momento sobre los efectos de la luz (continua y pulsada) en plantas y alimentos como su caracterización biológica con herramientas tecnológicas actuales LEDs, siendo un centro capaz de poseer el nivel de competitividad que otros laboratorios existentes en el mundo.')
    st_lottie(LED, height=350, key="codin")
   with b:
    st.write("---")
    st.subheader('💨Misión')
    st.write('Proyectar e impulsar el desarrollo de nuevas actividades en el sector agroindustrial a través de procedimientos que ayuden a mejorar la calidad de vida alrededor del mundo, generando productos agroalimentarios con valor agregado.')
    st_lottie(AG, height=350, key="codi")


with st.container():
  c,d = st.columns(2)

  with c:
   st.write("---")
   st.subheader('💨Visión')
   st.write('Ser un centro capaz de impulsar, desarrollar y fortalecer iniciativas que incentiven la productividad y rentabilidad agroalimentaria; generando en el sector agroindustrial nuevas filosofías de competitividad y calidad.')
   st_lottie(VI, height=350, key="cod")
  with d:
   st.write("---")
   st.subheader('💨¿Cómo se construyó LIA?')
   st.write('La adquisición de equipamiento en LIA se ha ido consolidando a través de diferentes apoyos federales y estatales tal es el caso de la Convocatoria de Infraestructura Científica y Tecnológica del CONACyT, la Convocatoria de Investigación Científica Básica 2016 que tuvo como objetivo apoyar únicamente propuestas de investigación científica básica que generen conocimiento de frontera y contribuyan a mejorar la calidad de la educación superior y a la formación de científicos y académicos.')
   st_lottie(CO, height=350, key="co")
    
  st.markdown("[CENTROS CONACYT🤖>](https://centrosconacyt.mx/quienes-somos/)")


DR = Image.open('/content/DR.jpg')
DES = Image.open('/content/DES.jpg')

with st.container():
   st.write("---")
   st.write("---")

   st.header('💦LINEAS DE INVESTIGACIÓN💦')
   st.write('Introducción. ')
   st.write('Podemos mencionar que LIA es el único laboratorio en el país especializado en iluminación artificial enfocado al uso de la radiación artificial multiespectral para el desarrollo de proyectos e investigación del sector agroindustrial. Se cuenta con cuatro líneas de investigación y desarrollo tecnológico las cuales se muestran a continuación: ')   
   a,b = st.columns(2)

   with a: 
    st.write("---")
    st.subheader('💨Sistemas de radiación artificial para cultivo de plantas')
    st.write('Profundizar y clariﬁcar los fenómenos no explicados hasta el momento sobre los efectos de la luz (continua y pulsada) en plantas y alimentos como su caracterización biológica con herramientas tecnológicas actuales LEDs, siendo un centro capaz de poseer el nivel de competitividad que otros laboratorios existentes en el mundo.')
    st.image(DR)
   with b:
    st.write("---")
    st.subheader('💨Sistemas de desinfección para productos del sector agroindustrial')
    st.write('Desarrollo de Sistemas de desinfección de alimentos con radiación ultravioleta LED tipo A, B y C aplicados a productos agroindustriales y en fresco.')
    st.image(DES)

dron= load_lottieurl('https://assets9.lottiefiles.com/packages/lf20_hdype8za.json')
al = load_lottieurl('https://assets4.lottiefiles.com/packages/lf20_dop0jnv7.json')

with st.container():
  c,d = st.columns(2)

  with c:
   st.write("---")
   st.subheader('💨Estrategias de luz para conservar y/o incrementar la vida de anaquel en productos frescos')
   st.write('Implementar estrategias tecnológicas con luz artificial tipo LED para preservar, extender y/o acelerar el tiempo de vida en almacén de frutas y verduras, además de analizar el efecto sobre la biosíntesis de compuestos (licopeno, capsaicina, entre otros.) durante su estancia en anaquel.')
   st_lottie(al, height=350, key="d")
  with d:
   st.write("---")
   st.subheader('💨Monitoreo y detección de plagas/enfermedades en cultivos')
   st.write('Investigación, integración y aplicación de la agricultura de precisión con el uso de tecnología aérea no tripulada (VANTs) para el monitoreo y detección de plagas en diferentes cultivos con el objetivo de evitar pérdidas en la producción.')
   st_lottie(dron, height=350, key="o")
    
  st.markdown("[CENTROS CONACYT🤖>](https://centrosconacyt.mx/quienes-somos/)")




DR2 = Image.open('/content/DR2.jpg')
DRA= Image.open('/content/DRA.jpg')
NOEL = Image.open('/content/NOEL.jpg')
MOI =  Image.open('/content/MOI.jpg')
RIC  = Image.open('/content/RIC.jpg')





with st.container():
   st.write("---")
   st.write("---")

   st.markdown("<h1 style='text-align: center; color: black;'>🌱LIA. NUESTRO EQUIPO🌱</h1>", unsafe_allow_html=True)
   st.markdown("<h1 style='text-align: center; color: green;'>🌱COORDINADORES E INVESTIGADORES🌱</h1>", unsafe_allow_html=True)

   st.write(' ')   
   a,b = st.columns(2)

   with a: 
    st.write("---")
    st.subheader('DR. JOSÉ ERNESTO OLVERA GONZÁLEZ')
    st.subheader('DIRECTOR')
    st.image(DR2)
   with b:
    st.write("---")
    st.subheader('DRA. NIVIA IRACEMI ESCALANTE GARCÍA')
    st.write('COORDINADORA GENERAL')
    st.image(DRA)

dron= load_lottieurl('https://assets9.lottiefiles.com/packages/lf20_hdype8za.json')
al = load_lottieurl('https://assets4.lottiefiles.com/packages/lf20_dop0jnv7.json')

with st.container():

  st.markdown("<h1 style='text-align: center; color: green;'>🌱PARTE DE NUESTROS ESTUDIANTES🌱</h1>", unsafe_allow_html=True)


  c,d,e = st.columns(3)
  with c:
   st.write("---")
   st.subheader('MTRO. NOEL MIJARES')
   st.write('ALUMNO DOCTORADO')
   st.image(NOEL)
  with d:
   st.write("---")
   st.subheader('ING. ROLANDO MOISÉS HINOJOSA MEZA')
   st.write('ALUMNO MAESTRÍA')
   st.image(MOI)
  with e:
   st.write("---")
   st.subheader('ING. RICARDO ROMERO LOMELÍ')
   st.write('ALUMNO MAESTRÍA')
   st.image(RIC)



  st.markdown("[PRODUCTOS GENERADOS 💯>](http://pabellon.tecnm.mx/LIA/productos_generados.html)")

  st.markdown("[VINCULACIÓN 🙆 >](http://pabellon.tecnm.mx/LIA/vinculacion.html)")

  st.markdown("[OFERTAS 🍭 >](http://pabellon.tecnm.mx/LIA/ofertas.html)")

  st.markdown("[EQUIPO COMPLET 🏅  >](http://pabellon.tecnm.mx/LIA/equipo.html#Alumnos)")


  st.markdown("<h2 style='text-align: center; color: grey;'>🌻GRACIAS POR VISITAR NUESTRO SITIO🌻</h2>", unsafe_allow_html=True)


  st.markdown("<h2 style='text-align: center; color: pink;'>🌻CUALQUIER DUDA, QUEJA O SUGERENCIA, NO DUDES EN CONTACTARNOS🌻</h2>", unsafe_allow_html=True)
# Out:
# Overwriting app.py

# %%
 # !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.199.201.201:8501
#
# npx: installed 22 in 6.31s
# your url is: https://tidy-coins-tie.loca.lt

# %% [markdown]
# #**FIN 🎈**
