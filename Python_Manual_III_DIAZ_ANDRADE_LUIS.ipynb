# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDAndrade/Basic-Computing/blob/main/Python_Manual_III_DIAZ_ANDRADE_LUIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TECNM | CAMPUS PABELLÓN DE ARTEAGA** ⚙️💡
#
# #**Master of Science in Mechatronics Engineering** 📊

# %% [markdown]
# ---
# ##**BASIC COMPUTING I 🧑🏻‍💻**
# ---
# ##***PYTHON MANUAL PART III Exploratory Data Analysis***  📚
#
# * **Professor: Dr. Francisco Villanueva Mejia👨🏻‍🏫**
#
# * **Student: Luis Bryant Díaz Andrade 🧑🏻‍💻**
#
# *Date: March 14th, 2023*
#
# ---

# %% [markdown]
# ---
# ***Introduction.***
#
# ***IN THIS NOTEBOOK WILL BE CARRIED OUT THE MANIPULATION AND TRANSMISSION OF STATISTICAL DATA, THESE DATA ARE COMPOSED OF GRADES OF UNITS 4, 5 AND 6 BROKEN DOWN BY STUDENTS, THESE DATA BELONG TO TECNM | CAMPUES PABELLÓN DE ARTEAGA, ARE OF STUDENTS OF THE CAREER OF MECHATRONICS ENGINEERING OF 3RD SEMESTER.***
#
# <img src="https://287524.fs1.hubspotusercontent-na1.net/hubfs/287524/Imported_Blog_Media/las-calificaciones-importan-o-no-al-buscar-empleo-2-Dec-17-2022-08-26-04-8310-PM.jpg" width="350px">

# %% [markdown]
# ---
#
# ##**i. Import our file to use.**
#
# ---

# %% [markdown]
# **We will continue using the grades of units 4, 5 and 6 of the subject "Electromagnetism" of the 3rd semester group of the Mechatronics Engineering course, belonging to Tecnm | Campus Pabellon de Arteaga.**
#
# 1. Download the dataset from the URL to the PC.
# 2. Go to the last icon in the sidebar on the left side of the screen ("Files").
# 3. Click on the first icon (a sheet of paper with an arrow pointing upwards) and select the previously downloaded file.
#
# 4. Right click on the file, and select "copy path".
# 5. Paste the path in the argument of `pd.read_csv()`, and add another parameter: `delimiter=""` , where we put between the quotation marks, which is the character that limits the different columns of the file.
#
# Note 1: Where it says "grades_im3.csv", To use other files, use: "FileYouChoose.csv".

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-431115dd-ea98-4cac-a61e-02468bab4618" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-431115dd-ea98-4cac-a61e-02468bab4618">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['grades_im3.csv']))
df
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1    211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2    211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3    211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4    211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
# 5    211050193   1       SERNA MEDINA YAHIR FERNANDO       70       70
# 6    211050154   1                VIVEROS CRUZ OSCAR       90       90
# 7    211050166   2             ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2          ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 10   211050160   2          MUÑOZ FLORES MARK ANTONY       98       98
# 11   211050171   2             NAJERA MATA ALEJANDRA       95       95
# ...

# %% [markdown]
# ##**ii. Importing modules that are not present in Google Collab**
#
# ---

# %% [markdown]
# **We can add new modules because we are using a "borrowed computer" from google, which contains Python 3. Using the "!" symbol we can execute commands as if we were using the terminal. In the case of Jupyter Notebooks, we use a type of Python command line console called IPython. This time we will install a statistics package called "Pinguoin". The command "pip install" will be used to download and install external libraries on this borrowed computer.**

# %% [markdown]
# **For example, we will import 'control' and 'pongouin', the latter will not help with our statistical analysis.**

# %%
# !pip install control
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.8/432.8 KB 7.8 MB/s eta 0:00:00
# ...

# %%
# !pip install pingouin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 KB 4.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=ef6c1303d2668f4205dc48a8f3d7a2a4f3788de0b5d37fb430c2fe19207b3459
#   Stored in directory: /root/.cache/pip/wheels/04/bb/0d/2d02ec45f29c48d6192476bfb59c5a0e64b605e7212374dd15
# Successfully built littleutils
# ...

# %% [markdown]
# **To perform a statistical analysis, which used to take hours to do in excel, Python helps us to make a statistical summary of all our data with the fucnion describe.**

# %%
df.describe()
# Out:
#               Eq     AVANCE1     AVANCE2    AVANCE3     AVANCE4   PROMEDIO  \
# count  31.000000   31.000000   31.000000  31.000000   31.000000  31.000000
# mean    2.935484   81.709677   81.548387  69.870968   79.709581  78.209581
# std     1.459120   28.171136   28.225094  25.023645   26.765962  26.765962
# min     1.000000    0.000000    0.000000   0.000000    2.000000   0.500000
# 25%     2.000000   80.000000   80.000000  70.000000   79.500000  78.000000
# 50%     3.000000   90.000000   90.000000  70.000000   87.333000  85.833000
# 75%     4.000000   95.000000   95.000000  85.000000   95.333000  93.833000
# max     5.000000  100.000000  100.000000  95.000000  100.333000  98.833000
#
#               DR        DRA       ITIC       IIND    CALIFU4   DOCUMENTO  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000   31.000000
# mean   67.318710  57.742581  65.807097  83.031613  71.819301   82.096774
# ...

# %% [markdown]
# ##**iii. Exploratory Data Analysis**
# ---

# %% [markdown]
# **Description of the dataset:**
#
# We will continue using the grades of units 4, 5 and 6 of the subject "Electromagnetism" of the 3rd semester group of the Mechatronics Engineering course, belonging to Tecnm | Campus Pabellon de Arteaga.*
#
# **Dataset Name:**
#
# califim3.csv
#
# URL: "C:\Users\luisd\Desktop\ARTÍCULOS\grades_im3.csv"
#
# **Number of students:**
#
# 30 students
#
# **Variables Information:**
#
# * Eq: Team
# * AVANCE1: Grade of Trail 1
# *AVANCE2: Grade of Trail 2
# *AVANCE3: Grade of Trail 3
# *AVANCE4: Grade of Trail 4
# *PROMEDIO: Trails Average
# * DR: Grade otorged by Dr. Noel
# *DRA: Grade otorged by Dra. Nivia
# *ITIC: Grade otorged by Ing. Ricardo
# *IIND: Grade otorged by Eng. Luis
# *CALIFU4: Unity 4 Grade
# *DOCUMENTO: Average Document
# *RUBRICAIND: Evaluation rubric
# *RUBRICAIND.1: Evaluation rubric 2
# *PRESENTACIÓN: Presentation Grade
# *CALIFU5: Unity 5 Grade
# *CALIFU6: Unity 6 Grade

# %% [markdown]
# ##**iv. Visualizations**
# ---

# %% [markdown]
# **Exploratory data analysis is an approach to analyze data sets and summarize their main characteristics, often with visual methods. Let's address some basic techniques to understand how the data behave and this could help us decide, for example, which methods to employ.**
#
# **First, as always, we need to import the dataset.**

# %%
#We import the necessary libraries:

import pandas as pd
import io
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
 
#We load the dataset:
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b99cdc4-5d9c-47ad-8c2b-b042d07f842e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b99cdc4-5d9c-47ad-8c2b-b042d07f842e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['grades_im3.csv']))
df
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1    211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2    211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3    211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4    211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
# 5    211050193   1       SERNA MEDINA YAHIR FERNANDO       70       70
# 6    211050154   1                VIVEROS CRUZ OSCAR       90       90
# 7    211050166   2             ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2          ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 10   211050160   2          MUÑOZ FLORES MARK ANTONY       98       98
# 11   211050171   2             NAJERA MATA ALEJANDRA       95       95
# ...

# %% [markdown]
# ##**v. Histograms**
# ---

# %% [markdown]
# **The histogram of the variable "CALIFU4" can be viewed with the .hist method of Matplotlib.**

# %%
#Plot histogram in Seaborn:

hist=sns.histplot(y="CALIFU4", data = df)

#title, axis titles, and tick size:
plt.title("U4 GRADES", fontsize=18)
hist.set_xlabel("STUDENTS",fontsize=14)
hist.set_ylabel("GRADE",fontsize=14)
hist.tick_params(labelsize=14)

# %%
#You can also make histograms of all the variables and display them together as a matrix.

df.hist(figsize=(12,12), color="violet")
plt.show()

# %% [markdown]
# ##**vi. Boxplots**
# ---

# %% [markdown]
# **Box-and-whisker plots (also known as boxplots) are a type of graph used to represent the distribution of a set of numerical data.**
#
# **The plot consists of a rectangle (the "box") extending from the first quartile (Q1) to the third quartile (Q3) of the data set. Within the box, a vertical line is drawn representing the median (the value that divides the data set into two equal parts).**
#
# **From the box, diagonal lines extending outward, called "whiskers," are drawn extending to the minimum and maximum values of the data set that are not outliers. Outliers are plotted as individual points beyond the whiskers.**
#
# **In summary, the box-and-whisker plot provides a visual way to view the variability, shape, and outliers of a data set. It is useful for identifying outliers and comparing distributions between different data sets.**
#
# **We can make this type of plots for each variable, this type of plot allows us, among other things, to easily visualize the outliers**

# %%
#Graph boxplot in Seaborn:

sns.boxplot(y='PROMEDIO',x="Eq", data = df,orient="v")

#title, axis titles, and tick size:
plt.title("TRAILS AVARAGE", fontsize=18)
hist.tick_params(labelsize=14)

# %%
#joint boxplots for all variables:
#We plot boxplots for all variables:

ax = sns.boxplot(data=df, orient="v", palette="rainbow")

#Specify figure size with Matplotlib, plt.gcf (which stands for Get current figure) is used: 

plt.gcf().set_size_inches(20, 10)
plt.show()

# %%
#I plot the boxplots again:
ax = sns.boxplot(data=df, orient="h", palette="rainbow")
#Set the x-axis scale to logarithmic scale:
ax.set_xscale('symlog')
#I specify from where to where I want the x-axis to plot me:
ax.axis(xmin=0, xmax=300)
#Set size of the figure:
plt.gcf().set_size_inches(25, 10)

# %% [markdown]
# **As we can see, the means of the data vary greatly. This occurs because the data are at different scales, which means that different units are used to measure different characteristics. It is possible to normalize or scale the data, which means to center the mean of the data. A common method is to standardize the variables by subtracting the column mean and dividing by the variance, by doing this, we are left with new values within each column for which μ=0 and σ=1 . Scikit-learn has a module for this called "preprocessing", which we will use in the next example. For more information on this, check the Scikit-learn documentation.**

# %%
#BECAUSE THE NAME OF THE STUDENTS IS NOT CONSIDERED AS A NUMBER AS SUCH, WE REMOVE THAT COLUMN AND STORE IT IN ANOTHER DF

df2 = df.drop(['ALUMNO'], axis =1)

# %%
#I import StandardScaler function from ScikitLearn library
from sklearn.preprocessing import StandardScaler

#I make a new object with the normalized data:
scaled = StandardScaler().fit_transform(df2)

#I make a new normalized dataframe, call it "df_scaled":
df_scaled = pd.DataFrame(data=scaled, columns=df2.columns)

#Graph boxplots of the variables of that new dataframe (with Seaborn):
ax = sns.boxplot(data=df_scaled, orient="h", palette="rainbow")

#set Seaborn plot figure size (with Matplotlib). 
plt.gcf().set_size_inches(10, 5)

# %% [markdown]
# **Another way to visualize multiple boxplots is in the form of a matrix. In this case, we use a function of the Pandas library called plot().**

# %%
#Graphic boxplots directly with Pandas, in the form of a 6 x 3 matrix :
df2.plot(kind='box',subplots=True,layout=(6,3),figsize=(8,8), color='red')
plt.tight_layout()

# %% [markdown]
# ##**vii. Violin Plots**
# ---

# %% [markdown]
# **Violin Plots can be used to visualize the information contained in a boxplot, i.e., the mean, quartiles, and maximum and minimum values, adding the information of the distribution of the data.**

# %%
sns.violinplot(x="PROMEDIO",data=df2)
# Out:
# <AxesSubplot:xlabel='PROMEDIO'>

# %%
sns.violinplot(x = 'AVANCE1', y = 'Eq', figsize=(20,20), data = df2, palette="rainbow")
# Out:
# <AxesSubplot:xlabel='AVANCE1', ylabel='Eq'>

# %% [markdown]
# ##**viii. Correlation Analysis**
#
# ---

# %% [markdown]
# **Another important aspect of understanding our data is to study the correlation between variables. If we want, for example, to see the correlation between the unit 6 grade and the equipment, we can make this scatter plot with marginal histograms using "sns.jointplot"**

# %%
joint_plt = sns.jointplot(y='Eq', x='CALIFU6', data=df2, kind='reg')

# %% [markdown]
# ##**ix. Pearson's Correlation Coefficient**
# ---

# %% [markdown]
# We can calculate the correlation between two variables with the Pearson correlation coefficient and the p-value.
#
# **The Pearson correlation coefficient ( ρ ) allows us to easily observe the linear dependencies between two datasets.**
#
# **A value of +1 means total positive linear correlation, 0 means no linear correlation, and -1, total negative linear correlation.**
# **Positive correlations imply that as x increases, so does y. Negative correlations imply that as x increases, y increases. Negative correlations imply that as x increases y decreases.**
#
# **The p-value indicates approximately the probability that the uncorrelated data sets have a Pearson correlation coefficient at least as extreme as that determined for those data sets. If this probability is less than 5% (P<0.05), it means that the correlation coefficient is statistically significant.**
#
# **Care must be taken because correlation does not imply causation. When two variables are correlated, there may or may not be a causal connection, and this connection may also be indirect.**

# %%
#I import the PearsonR function from the "stats" module SciPy library
from scipy.stats import pearsonr
def get_corr(col1, col2, temp_df):
    pearson_corr, p_value = pearsonr(temp_df[col1], temp_df[col2])
    print("The correlation between {} and {} is {:.2f}".format(col1, col2, pearson_corr))
    print("The P-value of this correlation is {:.1e}".format(p_value))
get_corr('AVANCE1', 'CALIFU4', df)
# Out:
# The correlation between AVANCE1 and CALIFU4 is 0.77
# The P-value of this correlation is 3.7e-07

# %% [markdown]
# ##**x. Heatmap**
# ---

# %% [markdown]
# **We can create a DataFrame with the Pearson correlation coefficient for each pair of columns (using the df.corr() function) and then use Matplotlib and Seaborn to create a heatmap of the coefficients.**

# %%
# We calculate the correlation with Pearson's coefficient using Pandas:
correlation = df2.corr(method='pearson')
# Create a new figure with Matplotlib and set the size:
fig=plt.gcf()
fig.set_size_inches(9,9)
# correlation heatmap using Seaborn:
sns.heatmap(correlation, annot=True,square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **When several variables are compared at the same time it is difficult to understand how the data behave. So we could add to the heatmap the coefficients of each comparison and plot only the lower triangular correlation matrix (since it is a symmetric plot, and the information in the upper triangle is redundant).**

# %%
import matplotlib.pyplot as plt
import numpy as np
correlation = df2.corr()
# np.triu es una función de Numpy que agarra un array en forma de matriz cuadrada y me da el triángulo superior de esa matriz cuadrada
upper_triangle = np.triu(correlation)
fig=plt.gcf()
fig.set_size_inches(10,10)
sns.heatmap(data=correlation,mask=upper_triangle,square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##**xi. Pair Plot**
# ---

# %% [markdown]
# **Another way to visualize the correlation between variables is to plot a correlation matrix with the Seaborn pairplot function. For example, here we plot the correlation of four of the columns of the dataset: 'PROMEDIO', 'CALIFU4', 'CALIFU5' and 'CALIFU6'.**

# %%
sns.pairplot(df[['PROMEDIO','CALIFU4','CALIFU5', 'CALIFU6']], corner=False)

# %%
sns.pairplot(df[['PROMEDIO','CALIFU4','CALIFU5', 'CALIFU6']], corner=True) #corner=True hides the upper portion of the matrix
