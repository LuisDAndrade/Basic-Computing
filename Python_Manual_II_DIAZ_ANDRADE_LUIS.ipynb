# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDAndrade/Basic-Computing/blob/main/Python_Manual_II_DIAZ_ANDRADE_LUIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TECNM | CAMPUS PABELLÓN DE ARTEAGA ⚙️💡**
#
# #**Master of Science in Mechatronics Engineering 📊**

# %% [markdown]
# ---
# ##**BASIC COMPUTING I 🧑🏻‍💻**
# ---
# ##***PYTHON MANUAL PART II***  📚
#
# * **Professor: Dr. Francisco Villanueva Mejia👨🏻‍🏫**
#
# * **Student: Luis Bryant Díaz Andrade 🧑🏻‍💻**
#
# *Date: March 07th, 2023*
#
# ---

# %% [markdown]
# ***i. This part of the manual will focus on following each of the steps to build a database that is easy to use and accessible.***

# %% [markdown]
# ##**I. FAIR Principles**
# ---

# %% [markdown]
# <img src="https://www.escueladerevisores.com/wp-content/uploads/2020/12/Imagen1.jpg" width="500px">
#
# *(FAIR Principles. Government of Spain. Ministry of Economic Affairs and Digital Transformation, 2023)*
#
#
#
# (Wilkinson et al., 2016). The FAIR Principles are a set of guiding principles for making research data easy to find, accessible, interoperable, and reusable. These principles provide guidance for scientific data management and directly address data producers and data publishers to promote maximum use of research data.
#
# {Alcalá, M., & Anglada, L. (2019)}. The most relevant elements that are integrated by the FAIR principles are:
#
# 1. Documents and Metadata: They allow data to be findable, reproducible, reusable and interoperable. The documentation takes into account the description of the collection process, provenance and the data itself (metadata).
# 2. Data formats: These define the extent of interoperability and reusability of the data. If possible, opt for an open format, contain embedded metadata and be sustainable.
# 3. Data access: In the first instance, do not publish confidential data. Plan, at the beginning of the project, what data can be shared and how to share it. If data cannot be shared, at least provide access to data metadata is expected to be provided.
# 4. Persistent identifiers: Allows data to be accurately findable, accessible and citable. In the case of data, there are Digital Object Identifiers (DOIs).
# Open data licensing: Allows data to be distributed freely or with as few restrictions as possible. It is recommended to opt for Creative Commons CC0 or CC0-BY 4.0.
#
# (Wilkinson, M. D., et al. 2019) The "FAIR" principle is a set of principles to ensure that data is easily found, accessible, interoperable and reusable. Some examples of how these principles can be applied:
#
# 1. Findable:
#
#  Provide a unique and permanent identifier for data (e.g., a DOI or digital object identifier).
# Use clear and accurate descriptive metadata to enable the data to be easily searched and found in catalogs or search engines.
# 2. Accessible:
#
#  Provide access to data free of charge or at a reasonable cost.
# Ensure that data is accessible to people with disabilities through the use of accessible technologies.
# 3. Interoperable:
#
#  Use standardized and widely accepted data formats to allow data to be shared and used by different systems.
# Include sufficient information in metadata to allow data to be interpreted correctly.
# 4. Reusable:
#
#  Publish the data under a clear license that allows the data to be reused and redistributed.
# Provide the data in a format that is easily processed and manipulated.
# By following these "FAIR" principles, the data become more useful and valuable to the scientific community and to other users who wish to use them.

# %% [markdown]
# ##**II. Documentation & Metadata**
# ---

# %% [markdown]
# **II.1 Metadata**
#
# Metadata is structured information that describes, explains, locates, or makes it easier to retrieve, use, or manage an information source. easier to retrieve, use or manage a source of information. Metadata is often referred to as data that is used to describe other data.
#
# Examples of metadata
#
# 1. Photographs and images. When taking a picture, many digital cameras include a series of metadata useful for further processing: shutter speed, aperture opening, focal length, chosen mode (automatic or manual), ISO speed, coordinates of the place where the shot was taken (if the camera is equipped with GPS), the camera model used, and so on. Subsequently, the photographer can add others such as the identity of the author, description of the scene or the corresponding keywords, which will make it easier to search in a database.
#
# 2. Written materials. In the form of metadata, the length (number of pages, words or characters), the content (a summary, an index of chapters, keywords, topics covered), the author, the date of creation, the type of content (whether it is a literary work, and if so, the genre to which it belongs, or a technical manual, or a legal text), and so on, can be displayed.
#
# 3. Videos. Some useful metadata in a recording, which can be added to those used in still photography, refer to the format in which they are recorded, their duration, their bitrate (bit rate: amount of information per unit of time, which will give you an idea of both their quality and file size), the date of recording and editing, the software used, the codec needed to play them, and so on. Much of this metadata is also used for sound-only recordings.
#
#
# **II.2 Documentation**
#
# The documentation provides the context: what the data were searched for, what the sources are, what limitations they have, who created the database, when, what was the last modification. Also to know if it is open access or if permissions are needed to modify it.
#
# *Metadata in a photo.*
#
# <img src="https://www.adslzone.net/app/uploads-adslzone.net/2021/05/metadatos.jpg" width="450px">
#
# *Metadata in a file.*
#
# <img src="https://ayudaleyprotecciondatos.es/wp-content/uploads/2020/09/metadatos-word-05.png" width="450px">

# %% [markdown]
# ##**III. Data Storage & Organization**
# ---

# %% [markdown]
# **III.1 Data Storage**
#
# Data storage refers to the process of saving information on a storage device for later use. There are different types of storage devices, each with its own advantages and disadvantages.
#
# 1. Hard disk: is a non-volatile storage device that uses magnetic disks to store data. It is widely used in desktop and laptop computers, and offers a large storage capacity and reasonably fast speed.
#
# 2. Flash memory: is a type of non-volatile storage that uses memory chips to store data. It is widely used in portable devices such as smartphones, digital cameras and USB flash drives due to its compact size, low power consumption and high speed.
#
# 3. Magnetic tape drives: are data storage devices in which data is stored on magnetic tapes. They are widely used in the audio and video recording industry, as well as in large-scale data backup.
#
# 4. Solid State Drives (SSD): are non-volatile storage devices that use flash memory chips to store data. They offer much faster speed than hard disks and are widely used in servers, workstations and laptops.
#
# 5. Cloud storage: is a form of online data storage that allows users to store and access their data over the Internet. Examples of cloud storage services include Dropbox, Google Drive, OneDrive and iCloud.
# <img src="https://imagekit.androidphoria.com/wp-content/uploads/mejores-nubes-personales-archivos-gratis.jpg" width="350px">
#
# How to organize data in the cloud?
#
#    1. Use a large number of folders and subfolders that can be organized according to date, type of instrument used, type of experiment, type of method, etc.
#    2. Name the files descriptively.
#    3. Do not use special characters (?!@*%{[<>) or spaces.
#    4.   Add a YYYYYYMMDD format to specify the date of the experiment (this will allow to organize the files chronologically).
#
#
# **III.2 Data Organization**
#
# Organizing data in spreadsheets is an important skill for anyone who works with data, whether professionally or personally. Here are some general guidelines for organizing data in spreadsheets:
#
# * Column headings: It is important to name each column so that it is easy to understand what type of data is stored in it. The headings should be clear and descriptive, and should be located in the top row of the spreadsheet.
# <img src="https://support.content.office.net/es-es/media/6ef5fec5-4bde-4b30-9546-4bea938c79a2.png" width="350px">
#
# * Rows and columns: Rows and columns should be used consistently. Generally, data is organized so that each row represents an entity or record, while each column represents an attribute or variable. For example, if you are organizing customer information, each row might represent a different customer and each column might represent information such as name, address, and phone number.
# <img src="https://www.automateexcel.com/excel/wp-content/uploads/2022/06/Datos-para-Varios-Niveles-de-Agrupamiento-en-Excel.png" width="350px">
#
# * Unique data: Each record should have a unique key so that it is easy to identify and search in the spreadsheet. For example, if you are organizing customer information, you could use each customer's ID number as a unique key.
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSMEimJVWp4Gv5CVKqUaQdA3efefxpAvHp7aw&usqp=CAU" width="350px">
#
# * Separate data: If you have data that can be separated into multiple columns, such as first and last names, or addresses in different fields, be sure to do so in order to use the information more effectively in future operations.
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSMEimJVWp4Gv5CVKqUaQdA3efefxpAvHp7aw&usqp=CAU" width="350px">
#
# * Consistent formatting: The data in a column should be in the same format to make it easier to analyze and visualize. For example, if you have a column of dates, make sure all dates are in the same format.
# <img src="https://www.redusers.com/noticias/wp-content/uploads/2013/08/JUL-011.jpg" width="350px">
#
#
# * Using tables: Use the table formatting tools in your spreadsheet to organize your data. Tables are useful for organizing and summarizing large data sets.
# <img src="https://i.ytimg.com/vi/1tt3iJMzUsw/maxresdefault.jpg" width="350px">
#
# * Empty data: Make sure that all cells are complete and that there is no missing data in your spreadsheet. If there is missing data, it is important to decide whether to delete the missing rows or cells or fill them with default values to avoid problems in future operations.
# <img src="https://aprendelibvrefiles.blob.core.windows.net/aprendelibvre-container/course/microsoft_excel_2010/image/excel10_11_01_l.png" width="350px">

# %% [markdown]
# ##**IV. Open Data.**
# ---

# %% [markdown]
# <img src="https://mercado.com.ar/wp/wp-content/uploads/2020/04/microsoft.jpg" width="450px">
#
#
# Open data is data that can be freely used, reused and redistributed by anyone, and is subject, at best, to the requirement of attribution and sharing in the same manner in which it appears.
#
# The main goal of open data is to increase transparency, accountability, and innovation by enabling citizens, researchers, and other stakeholders to access and analyze information that was previously unavailable or difficult to obtain. Open data can also help drive economic growth and create new opportunities for entrepreneurs and developers to build new applications and services.
#
# Examples of open data include government statistics, weather data, transportation schedules, and scientific research data. Many organizations and governments have created online portals or repositories where open data is made available to the public in various formats, including machine-readable formats that can be easily analyzed by computers.

# %% [markdown]
# ##**V. Pandas🐼**
#
# *(Pandas, 2023)* Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# The main features of this library are:
#
# * It defines new data structures based on the arrays of the NumPy library but with new functionalities.
#
# * It allows to easily read and write files in CSV format, Excel and SQL databases.
#
# * Allows access to data through indexes or names for rows and columns.
#
# * Provides methods for reordering, splitting and combining data sets.
#
# * Allows working with time series.
#
# * It performs all these operations very efficiently.

# %% [markdown]
# ###***For this work, we will be handling grade data from a 3rd semester Mechatronics Engineering group.***
#
# ---

# %% [markdown]
# **V.1 Dataframe from Scratch**

# %%
#We Import Necessary Libraries

import pandas as pd
import numpy as np

df_Sc = pd.DataFrame({"Alumno1": np.array([100,70,80, np.nan, 50, 100]), "Alumno2": np.array([60,np.nan,80,90,100, 60]), "Alumno3": np.array([100, 100, 100, 80, np.nan, 90]), 
                          "Alumno4": np.array([70, 50, 90, 50, 100, 70])})

#Function np.nan is an empty celtic 
#(In this example, np.nan is not aproviedd)

df_Sc
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 1     70.0      NaN    100.0       50
# 2     80.0     80.0    100.0       90
# 3      NaN     90.0     80.0       50
# 4     50.0    100.0      NaN      100
# 5    100.0     60.0     90.0       70

# %% [markdown]
# **V.2 Dataframe from PC**
#
# 1. Download the dataset from the URL to the PC.
# 2. Go to the last icon in the sidebar on the left side of the screen ("Files").
# 3. Click on the first icon (a sheet of paper with an arrow pointing upwards) and select the previously downloaded file.
#
# 4. Right click on the file, and select "copy path".
# 5. Paste the path in the argument of `pd.read_csv()`, and add another parameter: `delimiter=""` , where we put between the quotation marks, which is the character that limits the different columns of the file.
#
# Note 1: Where it says "grades_im3.csv", To use other files, use: "FileYouChoose.csv".

# %%
# !pip install control
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.8/432.8 KB 8.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7580b5d5-1338-4d52-bd7e-34f8383af6c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7580b5d5-1338-4d52-bd7e-34f8383af6c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['grades_im3.csv']))
df
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1    211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2    211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3    211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4    211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
# 5    211050193   1       SERNA MEDINA YAHIR FERNANDO       70       70
# 6    211050154   1                VIVEROS CRUZ OSCAR       90       90
# 7    211050166   2             ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2          ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 10   211050160   2          MUÑOZ FLORES MARK ANTONY       98       98
# 11   211050171   2             NAJERA MATA ALEJANDRA       95       95
# ...

# %% [markdown]
# **V.3 Import from a URL**
# If the dataset is on a web page, it can be uploaded to Google Colab by copying the URL and pasting it between the quotes in the command **df = pd.read_csv (" ")**. Other parameters can be added to refine the processing of this file. For example, the delimiter is a sequence of characters that separates regions in a plain text.

# %%
#EXAMPLE: (VILLANUEVA,2023)

import pandas as pd
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", delimiter=";")
df2=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", delimiter=";")

# %% [markdown]
# ##**VI. Preliminary Analysis**
# ---

# %% [markdown]
# *Let's play a little with some Pandas functions. To have an overview of how our dataset looks like we can use the functions head, tail, describe, info, shape, among others.*

# %%
#The head function shows me the first rows of the dataset, where n is the number of rows we want to display.
#For example, if I want to see the first 5 students. Since the header is line #0, we will set n to 5


df.head(n=5)
# Out:
#            NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0   211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1   211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2   211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3   211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4   211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
#
#    AVANCE3  AVANCE4  PROMEDIO    DR   DRA  ITIC  IIND  CALIFU4  DOCUMENTO  \
# 0       75   90.333    88.833  56.7  40.0  50.0  80.0     67.9         82
# 1       70   78.667    77.167  56.7  40.0  50.0  80.0     63.8         82
# 2       70   78.667    77.167  56.7  40.0  50.0  80.0     63.8         82
# 3       75   80.333    78.833  56.7  40.0  50.0  80.0     64.4         82
# 4       70   88.667    87.167  56.7  40.0  50.0  80.0     67.3         82
#
#    RUBRICAIND  RUBRICAIND.1  PRESENTACIÓN  CALIFU5    CALIFU6
# ...

# %%
# The tail function analogously shows me the last rows.
#For example, if I want to see the last 5 students.

df.tail(n=5)
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 26   211050183   5         GARZA ANDRADE ANGEL OSMAR       95       95
# 27   211050188   5  HERNANDEZ ESTRADA LEONARDO ANGEL        0        0
# 28   211050185   5   PEREZ CALDERA ANTHONY CRISTOFER        0        0
# 29   211050155   5        SABAS PEDROZA BRAYAN YAHIR       90       90
# 30   211050175   5    COLLAZO DE LUNA CARLOS EDUARDO       95       95
#
#     AVANCE3  AVANCE4  PROMEDIO    DR   DRA  ITIC  IIND    CALIFU4  DOCUMENTO  \
# 26       70   88.667    87.167  60.0  40.0  50.0  80.0  68.008333         50
# 27        0    2.000     0.500  60.0  40.0  50.0  80.0  37.675000         50
# 28        0    2.000     0.500  60.0  40.0  50.0  80.0  37.675000         50
# 29       60   82.000    80.500  60.0  40.0  50.0  80.0  65.675000         50
# 30       70   88.667    87.167  60.0  40.0  50.0  80.0  68.008333         50
#
#     RUBRICAIND  RUBRICAIND.1  PRESENTACIÓN  CALIFU5    CALIFU6
# ...

# %%
#It can be seen that we have 30 students, and 19 variables. A simpler way to do this count is with the Shape function:

df.shape
# Out:
# (31, 19)

# %%
#To perform a statistical analysis, which used to take hours to do in excel, Python helps us to make a statistical summary of all our data with the fucnion describe.

df.describe()
# Out:
#               Eq     AVANCE1     AVANCE2    AVANCE3     AVANCE4   PROMEDIO  \
# count  31.000000   31.000000   31.000000  31.000000   31.000000  31.000000
# mean    2.935484   81.709677   81.548387  69.870968   79.709581  78.209581
# std     1.459120   28.171136   28.225094  25.023645   26.765962  26.765962
# min     1.000000    0.000000    0.000000   0.000000    2.000000   0.500000
# 25%     2.000000   80.000000   80.000000  70.000000   79.500000  78.000000
# 50%     3.000000   90.000000   90.000000  70.000000   87.333000  85.833000
# 75%     4.000000   95.000000   95.000000  85.000000   95.333000  93.833000
# max     5.000000  100.000000  100.000000  95.000000  100.333000  98.833000
#
#               DR        DRA       ITIC       IIND    CALIFU4   DOCUMENTO  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000   31.000000
# mean   67.318710  57.742581  65.807097  83.031613  71.819301   82.096774
# ...

# %%
#To see the type of variable in each column, we can use the function info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NO            31 non-null     object
#  1   Eq            31 non-null     int64
#  2   ALUMNO        31 non-null     object
#  3   AVANCE1       31 non-null     int64
#  4   AVANCE2       31 non-null     int64
#  5   AVANCE3       31 non-null     int64
#  6   AVANCE4       31 non-null     float64
#  7   PROMEDIO      31 non-null     float64
#  8   DR            31 non-null     float64
#  9   DRA           31 non-null     float64
#  10  ITIC          31 non-null     float64
#  11  IIND          31 non-null     float64
#  12  CALIFU4       31 non-null     float64
#  13  DOCUMENTO     31 non-null     int64
#  14  RUBRICAIND    31 non-null     int64
#  15  RUBRICAIND.1  31 non-null     float64
#  16  PRESENTACIÓN  31 non-null     int64
#  17  CALIFU5       31 non-null     float64
# ...

# %%
# We can see how many students have any marks in unit 6.

df.value_counts('CALIFU6')
# Out:
# CALIFU6
# 100.000000    6
# 25.087500     3
# 40.254167     2
# 62.295833     1
# 76.129167     1
# 72.504167     1
# 68.879167     1
# 67.504167     1
# 66.795833     1
# 64.004167     1
# 63.504167     1
# 62.545833     1
# 60.729167     1
# 54.920833     1
# 39.087500     1
# 60.500000     1
# 60.295833     1
# 59.629167     1
# 57.545833     1
# 56.962500     1
# 56.295833     1
# 56.212500     1
# 60.629167     1
# dtype: int64

# %% [markdown]
# ##**VII. Data Extraction**
# ---

# %% [markdown]
# If we want to read a specific row and/or column we can use the *iloc* or *loc* functions.
#
# * loc gives me rows or columns that have a specific label.
# * iloc gives me rows or columns according to their position (integer).
#
# For example, suppose we want to extract the value of the 2nd row and 3rd column (index does not count as a column), whose value is 80:

# %%
print(df.loc[2, "AVANCE1"]) # Con loc especificamos el label del (row, column), en este caso la primera row 
                                  # tiene un label 0 (es el index) y la primera columna "fixed acidity"
print(df.iloc[2,3]) # Con iloc ponemos la posición del (row, column), siendo (0,0) en este caso.
# Out:
# 80
# 80

# %%
#To extract columns remembering Notebook 1, we have:
# First I see what columns I have

print(df.columns)

# Then I filter according to the name of the column I am interested in:
df["DR"][0:10]
# Out:
# Index(['NO', 'Eq', 'ALUMNO', 'AVANCE1', 'AVANCE2', 'AVANCE3', 'AVANCE4',
#        'PROMEDIO', 'DR', 'DRA', 'ITIC', 'IIND', 'CALIFU4', 'DOCUMENTO',
#        'RUBRICAIND', 'RUBRICAIND.1', 'PRESENTACIÓN', 'CALIFU5', 'CALIFU6'],
#       dtype='object')
# 0    56.7
# 1    56.7
# 2    56.7
# 3    56.7
# 4    56.7
# 5    56.7
# 6    56.7
# 7    95.0
# 8    95.0
# 9    95.0
# Name: DR, dtype: float64

# %%
#To extract a row I use iloc
#For example, i want to see the student number 5
df.iloc[5]
# Out:
# NO                                211050193
# Eq                                        1
# ALUMNO          SERNA MEDINA YAHIR FERNANDO
# AVANCE1                                  70
# AVANCE2                                  70
# AVANCE3                                  75
# AVANCE4                              73.667
# PROMEDIO                             72.167
# DR                                     56.7
# DRA                                    40.0
# ITIC                                   50.0
# IIND                                   80.0
# CALIFU4                                62.1
# DOCUMENTO                                82
# RUBRICAIND                               25
# RUBRICAIND.1                           10.0
# PRESENTACIÓN                             80
# CALIFU5                                53.0
# CALIFU6                           57.545833
# Name: 5, dtype: object

# %%
#Logical operators are used to filter data. Recalling Notebook 1, we had that:

df[df["AVANCE1"] == 100]
# Out:
#             NO  Eq                         ALUMNO  AVANCE1  AVANCE2  AVANCE3  \
# 13   211050157   3  BORJON MENDEZ EMILI ESTIBALIZ      100      100       80
# 18   211050186   3   ROSTRO GARCIA JANIE MARBELLE      100      100       70
# 24   211050173   4             PEREZ ROMO ERNESTO      100      100       95
#
#     AVANCE4  PROMEDIO         DR    DRA   ITIC       IIND    CALIFU4  \
# 13   95.333    93.833  73.333333  40.00  50.00  63.333333  70.508333
# 18   92.000    90.500  73.333333  40.00  50.00  63.333333  69.341667
# 24  100.333    98.833  53.330000  76.67  86.67  93.330000  83.760000
#
#     DOCUMENTO  RUBRICAIND  RUBRICAIND.1  PRESENTACIÓN  CALIFU5    CALIFU6
# 13         85          27          10.8            87    56.50  63.504167
# 18         85          25          10.0            88    55.75  62.545833
# 24         96          39          15.6           100    68.50  76.129167

# %%
#What if we want to filter based on multiple conditions? In Pandas the operators and and or are used as & and | respectively. 
#For example, we want the wines that have "AVANCE 1 == 100" but with ITIC higher than 80

df[(df["AVANCE1"] == 100) & (df["ITIC"] > 80)]
# Out:
#             NO  Eq              ALUMNO  AVANCE1  AVANCE2  AVANCE3  AVANCE4  \
# 24   211050173   4  PEREZ ROMO ERNESTO      100      100       95  100.333
#
#     PROMEDIO     DR    DRA   ITIC   IIND  CALIFU4  DOCUMENTO  RUBRICAIND  \
# 24    98.833  53.33  76.67  86.67  93.33    83.76         96          39
#
#     RUBRICAIND.1  PRESENTACIÓN  CALIFU5    CALIFU6
# 24          15.6           100     68.5  76.129167

# %%
#Another example is to filter out data with Eq 2 and higher or avance 1 higher than 90

df[(df["Eq"] == 2) | (df["AVANCE1"] > 90)].sort_values(["AVANCE1"], ascending = True)
# Out:
#             NO  Eq                           ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1        GONZALEZ HARUMY GUADALUPE       95       95
# 4    211050170   1          MENDEZ MARTINEZ JOHVANY       95       95
# 7    211050166   2            ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2         ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2    BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 11   211050171   2            NAJERA MATA ALEJANDRA       95       95
# 12   211050163   2        SERNA VALDEZ ISIS MARIOLI       95       95
# 15   211050168   3     MIRELES HERNANDEZ LUIS JOSUE       95       95
# 23   211050187   4  PEREZ CALDERA ALONSO QUETZALKEN       95       90
# 26   211050183   5        GARZA ANDRADE ANGEL OSMAR       95       95
# 30   211050175   5   COLLAZO DE LUNA CARLOS EDUARDO       95       95
# 10   211050160   2         MUÑOZ FLORES MARK ANTONY       98       98
# ...

# %% [markdown]
# ##**VIII. Data Modification**
# ---

# %%
#We can create or delete columns in the original dataframe. But it is more convenient to make these changes in a copy of the original dataframe:

new_df = df.copy()

# %%
#It may be convenient to define a new column that is an average of units 4, 5 and 6.

new_df["CALIFINAL"] = (new_df["CALIFU4"] + new_df["CALIFU5"]+ new_df["CALIFU6"])/3

new_df
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1    211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2    211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3    211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4    211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
# 5    211050193   1       SERNA MEDINA YAHIR FERNANDO       70       70
# 6    211050154   1                VIVEROS CRUZ OSCAR       90       90
# 7    211050166   2             ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2          ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 10   211050160   2          MUÑOZ FLORES MARK ANTONY       98       98
# 11   211050171   2             NAJERA MATA ALEJANDRA       95       95
# ...

# %%
#Once this has been done, it may be convenient to delete the columns with which we performed the operation. To do this we use the drop function

new_df = new_df.drop(columns = ["CALIFU4", "CALIFU5", "CALIFU6"])
new_df
# Out:
#             NO  Eq                            ALUMNO  AVANCE1  AVANCE2  \
# 0    211050164   1         GONZALEZ HARUMY GUADALUPE       95       95
# 1    211050162   1      ANDRADE OVALLE AARON GERARDO       80       80
# 2    211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80       80
# 3    211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80       80
# 4    211050170   1           MENDEZ MARTINEZ JOHVANY       95       95
# 5    211050193   1       SERNA MEDINA YAHIR FERNANDO       70       70
# 6    211050154   1                VIVEROS CRUZ OSCAR       90       90
# 7    211050166   2             ORTIZ DENZEL DE JESUS       95       95
# 8    211050153   2          ANDRADE PUGA ROMAN ATZIN       95       95
# 9    211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95       95
# 10   211050160   2          MUÑOZ FLORES MARK ANTONY       98       98
# 11   211050171   2             NAJERA MATA ALEJANDRA       95       95
# ...

# %%
#It is convenient to put the final grade in the first column. Thus,

cols = new_df.columns.tolist()

cols = cols[-1:] + cols[:-1]
new_df = new_df[cols]
new_df
# Out:
#     CALIFINAL          NO  Eq                            ALUMNO  AVANCE1  \
# 0   60.466667   211050164   1         GONZALEZ HARUMY GUADALUPE       95
# 1   56.281944   211050162   1      ANDRADE OVALLE AARON GERARDO       80
# 2   54.906944   211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80
# 3   56.204167   211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80
# 4   60.281944   211050170   1           MENDEZ MARTINEZ JOHVANY       95
# 5   57.548611   211050193   1       SERNA MEDINA YAHIR FERNANDO       70
# 6   59.643056   211050154   1                VIVEROS CRUZ OSCAR       90
# 7   98.233333   211050166   2             ORTIZ DENZEL DE JESUS       95
# 8   98.230556   211050153   2          ANDRADE PUGA ROMAN ATZIN       95
# 9   98.230556   211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95
# 10  98.630556   211050160   2          MUÑOZ FLORES MARK ANTONY       98
# 11  98.230556   211050171   2             NAJERA MATA ALEJANDRA       95
# ...

# %%
#We can also replace specific values with the replace function

new_df
# Out:
#     CALIFINAL          NO  Eq                            ALUMNO  AVANCE1  \
# 0   60.466667   211050164   1         GONZALEZ HARUMY GUADALUPE       95
# 1   56.281944   211050162   1      ANDRADE OVALLE AARON GERARDO       80
# 2   54.906944   211050169   1  CASILLAS HERNANDEZ GUSTAVO ANGEL       80
# 3   56.204167   211050156   1    HERNANDEZ SANCHEZ JUAN ALBERTO       80
# 4   60.281944   211050170   1           MENDEZ MARTINEZ JOHVANY       95
# 5   57.548611   211050193   1       SERNA MEDINA YAHIR FERNANDO       70
# 6   59.643056   211050154   1                VIVEROS CRUZ OSCAR       90
# 7   98.233333   211050166   2             ORTIZ DENZEL DE JESUS       95
# 8   98.230556   211050153   2          ANDRADE PUGA ROMAN ATZIN       95
# 9   98.230556   211050174   2     BUSTOS NIEVES EMMANUEL ISAIAS       95
# 10  98.630556   211050160   2          MUÑOZ FLORES MARK ANTONY       98
# 11  98.230556   211050171   2             NAJERA MATA ALEJANDRA       95
# ...

# %%
df_manual1 = new_df.copy()


df_manual1["Eq"] = df_manual1["Eq"].replace(1,'EXTRA')
df_manual1
# Out:
#     CALIFINAL          NO     Eq                            ALUMNO  AVANCE1  \
# 0   60.466667   211050164  EXTRA         GONZALEZ HARUMY GUADALUPE       95
# 1   56.281944   211050162  EXTRA      ANDRADE OVALLE AARON GERARDO       80
# 2   54.906944   211050169  EXTRA  CASILLAS HERNANDEZ GUSTAVO ANGEL       80
# 3   56.204167   211050156  EXTRA    HERNANDEZ SANCHEZ JUAN ALBERTO       80
# 4   60.281944   211050170  EXTRA           MENDEZ MARTINEZ JOHVANY       95
# 5   57.548611   211050193  EXTRA       SERNA MEDINA YAHIR FERNANDO       70
# 6   59.643056   211050154  EXTRA                VIVEROS CRUZ OSCAR       90
# 7   98.233333   211050166      2             ORTIZ DENZEL DE JESUS       95
# 8   98.230556   211050153      2          ANDRADE PUGA ROMAN ATZIN       95
# 9   98.230556   211050174      2     BUSTOS NIEVES EMMANUEL ISAIAS       95
# 10  98.630556   211050160      2          MUÑOZ FLORES MARK ANTONY       98
# ...

# %% [markdown]
# ###**IX. Working with missing values**
# ---

# %% [markdown]
# A very common thing that can happen when building a database is that we have NaN values (**N**ot **A** **N**umber, i.e. cells without values for different reasons (impossible to measure, lost, etc.). Let's see if the wine dataset contains missing values:

# %%
import pandas as pd
import numpy as np

df_Sc = pd.DataFrame({"Alumno1": np.array([100,70,80, np.nan, 50, 100]), "Alumno2": np.array([60,np.nan,80,90,100, 60]), "Alumno3": np.array([100, 100, 100, 80, np.nan, 90]), 
                          "Alumno4": np.array([70, 50, 90, 50, 100, 70])})

#Function np.nan is an empty celtic 
#(In this example, np.nan is not aproviedd)
df_Sc
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 1     70.0      NaN    100.0       50
# 2     80.0     80.0    100.0       90
# 3      NaN     90.0     80.0       50
# 4     50.0    100.0      NaN      100
# 5    100.0     60.0     90.0       70

# %%
df_Sc.isnull().sum()
# Out:
# Alumno1    1
# Alumno2    1
# Alumno3    1
# Alumno4    0
# dtype: int64

# %%
#First we can check which values are NaN with a boolean:


pd.isna(df_Sc)
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    False    False    False    False
# 1    False     True    False    False
# 2    False    False    False    False
# 3     True    False    False    False
# 4    False    False     True    False
# 5    False    False    False    False

# %%
'''Then, here we have 2 options: delete the rows that contain NaN values or replace these NaN values by something that has some kind of sense in the dataframe.

The first option is the easiest, but it implies losing the whole row where in other columns there may be values:'''

df_manual1 = df_Sc.copy()
df_manual1.dropna(how="any")

#The how parameter can be "any" or "all". If it is the former, the entire row or column is deleted if it contains at least
# one NaN value. If "all", the row or column is deleted only if ALL elements are NaN.
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 2     80.0     80.0    100.0       90
# 5    100.0     60.0     90.0       70

# %%
'''
Now let's look at the "difficult" option. To replace these values there are many options, some more sophisticated than others:

Replace by some specific value (a scalar).
Replace by the average/median of the column
Replace with some built-in method offered by Pandas
Replace using some algorithm; for example, some algorithms that do it automatically.


'''

df_manual2 = df_Sc.copy()
df_manual2.fillna(70)
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 1     70.0     70.0    100.0       50
# 2     80.0     80.0    100.0       90
# 3     70.0     90.0     80.0       50
# 4     50.0    100.0     70.0      100
# 5    100.0     60.0     90.0       70

# %%
# We replace with the average of each column
df_manual2 = df_Sc.copy()
df_manual2.fillna(df_manual2.mean())
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 1     70.0     78.0    100.0       50
# 2     80.0     80.0    100.0       90
# 3     80.0     90.0     80.0       50
# 4     50.0    100.0     94.0      100
# 5    100.0     60.0     90.0       70

# %% [markdown]
# ###**X. Elimination of duplicates**
# ---

# %% [markdown]
# Another problem that can arise in addition to missing values are duplicate values. Let's see how to identify and eliminate them:

# %%
df_manual2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
# Then, we remove the duplicates by doing:

df_manual2.drop_duplicates()
# Out:
#    Alumno1  Alumno2  Alumno3  Alumno4
# 0    100.0     60.0    100.0       70
# 1     70.0      NaN    100.0       50
# 2     80.0     80.0    100.0       90
# 3      NaN     90.0     80.0       50
# 4     50.0    100.0      NaN      100
# 5    100.0     60.0     90.0       70

# %% [markdown]
# ###**XI. Concatenate dataframes**
# ---

# %% [markdown]
# The function to concatenate dataframes. Taking into account that we have a database of red and white wines, it is of interest to merge them and add a categorical variable hue, which can be used as a basis for the concatenation of dataframes.

# %%
import pandas as pd
import numpy as np

df_Sc = pd.DataFrame({"Alumno1": np.array([100,70,80, 90, 50, 100]), "Alumno2": np.array([60,np.nan,80,90,100, 60]), "Alumno3": np.array([100, 100, 100, 80, np.nan, 90]), 
                          "Alumno4": np.array([70, 50, 90, 50, 100, 70])})

df_Sc['hue']='GROUPA'



df_Scb = pd.DataFrame({"Alumno1": np.array([90,70,80, 90, 59, 86]), "Alumno2": np.array([89,56,80,90,100, 60]), "Alumno3": np.array([100, 89, 100, 90, 73, 90]), 
                          "Alumno4": np.array([74, 50, 87, 80, 40, 70])})

df_Scb['hue']='GROUPB'

df_im = pd.concat([df_Sc, df_Scb], ignore_index=True)
df_im
# Out:
#     Alumno1  Alumno2  Alumno3  Alumno4     hue
# 0       100     60.0    100.0       70  GROUPA
# 1        70      NaN    100.0       50  GROUPA
# 2        80     80.0    100.0       90  GROUPA
# 3        90     90.0     80.0       50  GROUPA
# 4        50    100.0      NaN      100  GROUPA
# 5       100     60.0     90.0       70  GROUPA
# 6        90     89.0    100.0       74  GROUPB
# 7        70     56.0     89.0       50  GROUPB
# 8        80     80.0    100.0       87  GROUPB
# 9        90     90.0     90.0       80  GROUPB
# 10       59    100.0     73.0       40  GROUPB
# 11       86     60.0     90.0       70  GROUPB

# %%
#We count and display the amount of data per group.

df_im.value_counts("hue")
# Out:
# hue
# GROUPA    6
# GROUPB    6
# dtype: int64

# %% [markdown]
# ###**XI. Dinamic Tables**
# ---

# %% [markdown]
# It is of interest to have 2 categorical variables, hue and quality, to make a pivot table as in Excel.
#
# Pivot tables (or pivot tables) are a common tool in spreadsheets such as Microsoft Excel or Google Sheets that allow you to summarize large amounts of data in a table that is easier to analyze.
#
# For this, we need to define:
#
# * The rows or index
# *The columns
# *The values that can be averages, maximum values, minimum values, sums, etc.

# %%
#It may be convenient to define a new column that is an average of units 4, 5 and 6.

df_im["PROMEDIO"] = (df_im["Alumno1"] + df_im["Alumno2"]+ df_im["Alumno3"]+ df_im["Alumno4"])/4
df_im["CALIF"] = (df_im["Alumno1"] + df_im["Alumno2"]+ df_im["Alumno3"]+ df_im["Alumno4"])/5


df_im
# Out:
#     Alumno1  Alumno2  Alumno3  Alumno4     hue  PROMEDIO  CALIF
# 0       100     60.0    100.0       70  GROUPA     82.50   66.0
# 1        70      NaN    100.0       50  GROUPA       NaN    NaN
# 2        80     80.0    100.0       90  GROUPA     87.50   70.0
# 3        90     90.0     80.0       50  GROUPA     77.50   62.0
# 4        50    100.0      NaN      100  GROUPA       NaN    NaN
# 5       100     60.0     90.0       70  GROUPA     80.00   64.0
# 6        90     89.0    100.0       74  GROUPB     88.25   70.6
# 7        70     56.0     89.0       50  GROUPB     66.25   53.0
# 8        80     80.0    100.0       87  GROUPB     86.75   69.4
# 9        90     90.0     90.0       80  GROUPB     87.50   70.0
# 10       59    100.0     73.0       40  GROUPB     68.00   54.4
# 11       86     60.0     90.0       70  GROUPB     76.50   61.2

# %%
pivot_table = df_im.pivot_table(index='PROMEDIO', columns='hue', values='CALIF')
pivot_table
# Out:
# hue       GROUPA  GROUPB
# PROMEDIO
# 66.25        NaN    53.0
# 68.00        NaN    54.4
# 76.50        NaN    61.2
# 77.50       62.0     NaN
# 80.00       64.0     NaN
# 82.50       66.0     NaN
# 86.75        NaN    69.4
# 87.50       70.0    70.0
# 88.25        NaN    70.6

# %%
pivot_table["GROUPA%"] = (pivot_table["GROUPA"]/6)
pivot_table["GROUPB%"] = (pivot_table["GROUPA"]/6)
pivot_table
# Out:
# hue       GROUPA  GROUPB    GROUPA%    GROUPB%
# PROMEDIO
# 66.25        NaN    53.0        NaN        NaN
# 68.00        NaN    54.4        NaN        NaN
# 76.50        NaN    61.2        NaN        NaN
# 77.50       62.0     NaN  10.333333  10.333333
# 80.00       64.0     NaN  10.666667  10.666667
# 82.50       66.0     NaN  11.000000  11.000000
# 86.75        NaN    69.4        NaN        NaN
# 87.50       70.0    70.0  11.666667  11.666667
# 88.25        NaN    70.6        NaN        NaN

# %% [markdown]
# ###**XII. Statistics with Groupby**
# ---

# %% [markdown]
# Something similar to pivot tables, but not exactly the same, consists of grouping values based on a category and looking at statistical parameters such as averages, maximums, minimums, etc. For this we use the *group_by* function:

# %%
df_im.groupby(["hue"]).mean()
# Out:
#           Alumno1    Alumno2    Alumno3    Alumno4  PROMEDIO  CALIF
# hue
# GROUPA  81.666667  78.000000  94.000000  71.666667    81.875   65.5
# GROUPB  79.166667  79.166667  90.333333  66.833333    78.875   63.1

# %% [markdown]
# Remove possible outliers that are biasing the average.
# Perform a statistical test between the means
# The former will be discussed in more detail in the section on Exploitative Data Analysis (EDA).
#
# Notice that in the remaining variables the differences are much more significant.
#
# What about a classification algorithm to predict quality? Let's do exactly the same:

# %%
df_im.groupby(["PROMEDIO"]).mean().sort_values("CALIF", ascending = False)
# Out:
#           Alumno1  Alumno2  Alumno3  Alumno4  CALIF
# PROMEDIO
# 88.25        90.0     89.0    100.0     74.0   70.6
# 87.50        85.0     85.0     95.0     85.0   70.0
# 86.75        80.0     80.0    100.0     87.0   69.4
# 82.50       100.0     60.0    100.0     70.0   66.0
# 80.00       100.0     60.0     90.0     70.0   64.0
# 77.50        90.0     90.0     80.0     50.0   62.0
# 76.50        86.0     60.0     90.0     70.0   61.2
# 68.00        59.0    100.0     73.0     40.0   54.4
# 66.25        70.0     56.0     89.0     50.0   53.0

# %% [markdown]
# ###**XIII. Table Personalization**
# ---

# %%
#One possibility is to highlight values with a specific color. For example:

df_im.style.highlight_min(color = "violet").highlight_max(color = "yellow").highlight_null()
# Out:
# <style type="text/css">
# #T_cb2e4_row0_col0, #T_cb2e4_row0_col2, #T_cb2e4_row1_col2, #T_cb2e4_row2_col2, #T_cb2e4_row4_col1, #T_cb2e4_row4_col3, #T_cb2e4_row5_col0, #T_cb2e4_row6_col2, #T_cb2e4_row6_col4, #T_cb2e4_row6_col5, #T_cb2e4_row6_col6, #T_cb2e4_row7_col4, #T_cb2e4_row8_col2, #T_cb2e4_row8_col4, #T_cb2e4_row9_col4, #T_cb2e4_row10_col1, #T_cb2e4_row10_col4, #T_cb2e4_row11_col4 {
#   background-color: yellow;
# }
# #T_cb2e4_row0_col4, #T_cb2e4_row1_col4, #T_cb2e4_row2_col4, #T_cb2e4_row3_col4, #T_cb2e4_row4_col0, #T_cb2e4_row4_col4, #T_cb2e4_row5_col4, #T_cb2e4_row7_col1, #T_cb2e4_row7_col5, #T_cb2e4_row7_col6, #T_cb2e4_row10_col2, #T_cb2e4_row10_col3 {
#   background-color: violet;
# }
# #T_cb2e4_row1_col1, #T_cb2e4_row1_col5, #T_cb2e4_row1_col6, #T_cb2e4_row4_col2, #T_cb2e4_row4_col5, #T_cb2e4_row4_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_cb2e4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
df_im.style.background_gradient()
# Out:
# <style type="text/css">
# #T_49044_row0_col0, #T_49044_row0_col2, #T_49044_row1_col2, #T_49044_row2_col2, #T_49044_row4_col1, #T_49044_row4_col3, #T_49044_row5_col0, #T_49044_row6_col2, #T_49044_row6_col5, #T_49044_row6_col6, #T_49044_row8_col2, #T_49044_row10_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_49044_row0_col1, #T_49044_row5_col1, #T_49044_row11_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_49044_row0_col3, #T_49044_row5_col3, #T_49044_row11_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_49044_row0_col5, #T_49044_row0_col6 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_49044_row1_col0, #T_49044_row7_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_49044_row1_col1, #T_49044_row1_col5, #T_49044_row1_col6, #T_49044_row4_col2, #T_49044_row4_col5, #T_49044_row4_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_49044_row1_col3, #T_49044_row3_col3, #T_49044_row7_col3 {
# ...

# %%
df_im.style.set_properties(**{'background-color': 'violet', 'border': 'solid red'}, color="solid black")
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ###**XIV. Saving and exporting data**
# ---

# %%
#Once we have made all the modifications to our database, it is time to save and export it in the desired format. For that we can:

# Formato csv
df_im.to_csv("CALIF_dataset_.csv", index = False)
# Formato xlsx
df_im.to_excel("CALIF_dataset_.xlsx", index = False)
# Formato txt
df_im.to_csv("CALIF_DATASET.txt", index = False, sep = "\t")
